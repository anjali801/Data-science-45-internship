# %%
# importing the library  or module
import math
print(math.pi)
print(math.factorial(5))
print(math.sqrt(2))
print(math.pow(2,4))
print(math.degrees)
print(math.floor(10.345))
print(math.ceil(10.345))

print("\n")

# Another:
import math as anna

print(anna.pi)
print(anna.factorial(10))
print(anna.sqrt(125))
print(anna.pow(4,4))


print("\n")
# Another way :-
from math import pi , factorial

print(factorial(7))
print(pi)

print("\n")
# Another way :-
from math import *

print(factorial(9))
print(pi)
print(floor(9.378))
print(ceil(9.378))
# Out:
# 3.141592653589793
# 120
# 1.4142135623730951
# 16.0
# <built-in function degrees>
# 10
# 11
#
#
# 3.141592653589793
# 3628800
# 11.180339887498949
# 256.0
#
#
# 5040
# 3.141592653589793
#
#
# 362880
# 3.141592653589793
# 9
# 10
