# %%
import pandas as pd
l = [1,2,3,4,5]
df = pd.Series(l)
print(df)

# Another example :
d = {"name":"Anjali","age":21,"city":"jaipur"}
df = pd.Series(data=d,index=["name","age","city"])
print("\n",df)
# help(pd.Series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
#  name    Anjali
# age         21
# city    jaipur
# dtype: object

# %%
import pandas as pd
d={
    "name":["kunal","dheeraj","Anjali","praveen","yash","danish"],
    "roll no":[12,34,56,19,78,15]
}

df = pd.DataFrame(data=d)
print(df)
# Out:
#       name  roll no
# 0    kunal       12
# 1  dheeraj       34
# 2   Anjali       56
# 3  praveen       19
# 4     yash       78
# 5   danish       15
