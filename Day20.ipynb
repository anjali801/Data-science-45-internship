# %% [markdown]
# # Sql
# -> My Sql
#
# -> Ms sql

# %% [markdown]
# # Database :
# It is the collection of the data in a format that can easily accessed
#
# #Types of the Database :
# -> Relational : Data store in table
#
# ->Non-Relational (NOSQL): Data not store in table

# %% [markdown]
# #What is SQL?
#
# SQL
# (Structured Query Language)
#
# -> SQL is a programming language used to interact with relational databases.
#
# # It is used to perform CRUD operations :
#
# -Create
#
# -Read
#
# -Update
#
# -Delete
