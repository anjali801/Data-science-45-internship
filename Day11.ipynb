# %% [markdown]
#  #Pandas

# %% [markdown]
# What is the Pandas ?
#
# Pandasa is a python library used for :
#
# 1 Reading data
#
# 2 Clearning data
#
# 3 Analzing data
#
# 4 Manipulating data

# %% [markdown]
# import pandas
#
# import pandas as pd

# %%
import pandas as pd
df = pd.Series([10,20,30])
print(df)
print(type(df))
print(df[0])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# <class 'pandas.core.series.Series'>
# 10

# %%
# dict :
# all the values are given necessary
import pandas as pd
dict = {"name":["dheeraj","kunal","prveen","abhishek","Anjali"],
        "Age":[20,23,22,24,21],
        "salary":[10000,20000,30000,40000,50000]}
df = pd.DataFrame(dict)
print(df)
print(type(df))
# Out:
#        name  Age  salary
# 0   dheeraj   20   10000
# 1     kunal   23   20000
# 2    prveen   22   30000
# 3  abhishek   24   40000
# 4    Anjali   21   50000
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# CSV , json, excel
#
#  Difference  between CVS , json , excel :

# %%
# CVS :
import pandas as pd
url = "https://raw.githubusercontent.com/anjali801/Data-science-45-internship/main/file1.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567
